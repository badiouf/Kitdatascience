# %%
import requests
import pandas

# %%
def get_country(IP):
    url='http://api.ipstack.com/'+IP+'?access_key=64b105cf1c49756f728f97051fd85da4'
    data=requests.get(url).json()
    pays=data['country_name']   
    return pays 

def get_money(IP):
    url='https://api.ipdata.co/'+IP+'?api-key=test'
    data=requests.get(url).json()
    response=data['currency']
    monnaie=response['name']    
    return monnaie

# %%
products['country']=[get_country(IP) for IP in products['ip_address']]

# %%
products
# Out:
#            username       ip_address                         product  \
# 0          ldrover0  666.666.666.666              Clam - Cherrystone
# 1          kizakov1             nope    Soup - Campbells Bean Medley
# 2          abromet2   240.177.79.234         Island Oasis - Lemonade
# 3      kkarolowski3    26.191.237.49        Water - Mineral, Natural
# 4         mbuckney4    58.90.204.239                Radish - Pickled
# 5       bsnozzwell5     226.52.32.70                    Oil - Sesame
# 6       afairholme6  127.197.204.119            Chicken - Tenderloin
# 7          avowdon7    189.169.17.54            Dc Hikiage Hira Huba
# 8         epridham8  187.129.113.105                      Dried Figs
# 9         tkendrew9    22.32.234.215             Pop - Club Soda Can
# 10        cjagielaa   75.254.207.163                  Cinnamon Rolls
# 11         jdolbeyb    17.105.113.72                 Wine - Ice Wine
# 12       chaylandsc   208.239.186.79        Chicken Thigh - Bone Out
# ...

# %%
#Cleaning data

#Suppression des IP invalides 
products=products.dropna(subset=['country'])

# %%
#Intégration du currency dans la table

products['currency']=[get_money(IP) for IP in products['ip_address']]
# Out:
# /home/bdiouf/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
products
# Out:
#            username       ip_address                        product  \
# 4         mbuckney4    58.90.204.239               Radish - Pickled
# 7          avowdon7    189.169.17.54           Dc Hikiage Hira Huba
# 8         epridham8  187.129.113.105                     Dried Figs
# 10        cjagielaa   75.254.207.163                 Cinnamon Rolls
# 11         jdolbeyb    17.105.113.72                Wine - Ice Wine
# 12       chaylandsc   208.239.186.79       Chicken Thigh - Bone Out
# 13        mvidelerd     116.18.56.20            Trout Rainbow Whole
# 14         jmulvine    87.198.88.207           Bread Crumbs - Panko
# 15     kcaldeyrouxf    138.44.156.99              Vector Energy Bar
# 16           ctaftg    18.61.195.234           Versatainer Nc - 888
# 17        ksumptonh   150.214.20.140     Bagel - Ched Chs Presliced
# 18          aloweri  157.197.190.113                        Dry Ice
# 19         sgarmeyj    219.75.213.15   Nantucket - Kiwi Berry Cktl.
# ...

# %%
#Création des variables booléennes dans la table products

products['SUGAR'] = products.infos.str.count('sugar')==1
products['PEANUT'] = products.infos.str.count('peanut')==1
products['FISH'] = products.infos.str.count('fish')==1
products['MUSTARD'] = products.infos.str.count('mustard')==1
products['GLUTEN'] = products.infos.str.count('gluten')==1
products['EGG'] = products.infos.str.count('egg')==1
products['MILK'] = products.infos.str.count('milk')==1
products['SOJA'] = products.infos.str.count('soja')==1
# Out:
# /home/bdiouf/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/bdiouf/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/bdiouf/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
products
# Out:
#            username       ip_address                        product  \
# 4         mbuckney4    58.90.204.239               Radish - Pickled
# 7          avowdon7    189.169.17.54           Dc Hikiage Hira Huba
# 8         epridham8  187.129.113.105                     Dried Figs
# 10        cjagielaa   75.254.207.163                 Cinnamon Rolls
# 11         jdolbeyb    17.105.113.72                Wine - Ice Wine
# 12       chaylandsc   208.239.186.79       Chicken Thigh - Bone Out
# 13        mvidelerd     116.18.56.20            Trout Rainbow Whole
# 14         jmulvine    87.198.88.207           Bread Crumbs - Panko
# 15     kcaldeyrouxf    138.44.156.99              Vector Energy Bar
# 16           ctaftg    18.61.195.234           Versatainer Nc - 888
# 17        ksumptonh   150.214.20.140     Bagel - Ched Chs Presliced
# 18          aloweri  157.197.190.113                        Dry Ice
# 19         sgarmeyj    219.75.213.15   Nantucket - Kiwi Berry Cktl.
# ...
